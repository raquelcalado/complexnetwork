# %%
import nltk
import itertools as it
import networkx as nx
import matplotlib.pyplot as plt
from nltk.tokenize import sent_tokenize

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
text = 'Existe um provérbio muito antigo que fala que não importa quantos passos você deu para trás. ' \
       'Importante mesmo é quantos passos agora você vai dar pra frente. É preciso que se mude o jeito de agir.' \
       'Procurando sempre dar passados para frente.'

# %%
tokenized_sentences = sent_tokenize(text)
print(tokenized_sentences)
# Out:
# ['Existe um provérbio muito antigo que fala que não importa quantos passos você deu para trás.', 'Importante mesmo é quantos passos agora você vai dar pra frente.', 'É preciso que se mude o jeito de agir.Procurando sempre dar passados para frente.']

# %%
array_of_tokens = []
for item in tokenized_sentences:
    without_accentuation = item.replace('.', '')
    array_of_tokens.append(nltk.word_tokenize(without_accentuation))
print(array_of_tokens)
# Out:
# [['Existe', 'um', 'provérbio', 'muito', 'antigo', 'que', 'fala', 'que', 'não', 'importa', 'quantos', 'passos', 'você', 'deu', 'para', 'trás'], ['Importante', 'mesmo', 'é', 'quantos', 'passos', 'agora', 'você', 'vai', 'dar', 'pra', 'frente'], ['É', 'preciso', 'que', 'se', 'mude', 'o', 'jeito', 'de', 'agirProcurando', 'sempre', 'dar', 'passados', 'para', 'frente']]

# %%
edgelist = [edge for phrase in array_of_tokens for edge in it.combinations(phrase, 2)]
print(edgelist)
# Out:
# [('Existe', 'um'), ('Existe', 'provérbio'), ('Existe', 'muito'), ('Existe', 'antigo'), ('Existe', 'que'), ('Existe', 'fala'), ('Existe', 'que'), ('Existe', 'não'), ('Existe', 'importa'), ('Existe', 'quantos'), ('Existe', 'passos'), ('Existe', 'você'), ('Existe', 'deu'), ('Existe', 'para'), ('Existe', 'trás'), ('um', 'provérbio'), ('um', 'muito'), ('um', 'antigo'), ('um', 'que'), ('um', 'fala'), ('um', 'que'), ('um', 'não'), ('um', 'importa'), ('um', 'quantos'), ('um', 'passos'), ('um', 'você'), ('um', 'deu'), ('um', 'para'), ('um', 'trás'), ('provérbio', 'muito'), ('provérbio', 'antigo'), ('provérbio', 'que'), ('provérbio', 'fala'), ('provérbio', 'que'), ('provérbio', 'não'), ('provérbio', 'importa'), ('provérbio', 'quantos'), ('provérbio', 'passos'), ('provérbio', 'você'), ('provérbio', 'deu'), ('provérbio', 'para'), ('provérbio', 'trás'), ('muito', 'antigo'), ('muito', 'que'), ('muito', 'fala'), ('muito', 'que'), ('muito', 'não'), ('muito', 'importa'), ('muito', 'quantos'), ('muito', 'passos'), ('muito', 'você'), ('muito', 'deu'), ('muito', 'para'), ('muito', 'trás'), ('antigo', 'que'), ('antigo', 'fala'), ('antigo', 'que'), ('antigo', 'não'), ('antigo', 'importa'), ('antigo', 'quantos'), ('antigo', 'passos'), ('antigo', 'você'), ('antigo', 'deu'), ('antigo', 'para'), ('antigo', 'trás'), ('que', 'fala'), ('que', 'que'), ('que', 'não'), ('que', 'importa'), ('que', 'quantos'), ('que', 'passos'), ('que', 'você'), ('que', 'deu'), ('que', 'para'), ('que', 'trás'), ('fala', 'que'), ('fala', 'não'), ('fala', 'importa'), ('fala', 'quantos'), ('fala', 'passos'), ('fala', 'você'), ('fala', 'deu'), ('fala', 'para'), ('fala', 'trás'), ('que', 'não'), ('que', 'importa'), ('que', 'quantos'), ('que', 'passos'), ('que', 'você'), ('que', 'deu'), ('que', 'para'), ('que', 'trás'), ('não', 'importa'), ('não', 'quantos'), ('não', 'passos'), ('não', 'você'), ('não', 'deu'), ('não', 'para'), ('não', 'trás'), ('importa', 'quantos'), ('importa', 'passos'), ('importa', 'você'), ('importa', 'deu'), ('importa', 'para'), ('importa', 'trás'), ('quantos', 'passos'), ('quantos', 'você'), ('quantos', 'deu'), ('quantos', 'para'), ('quantos', 'trás'), ('passos', 'você'), ('passos', 'deu'), ('passos', 'para'), ('passos', 'trás'), ('você', 'deu'), ('você', 'para'), ('você', 'trás'), ('deu', 'para'), ('deu', 'trás'), ('para', 'trás'), ('Importante', 'mesmo'), ('Importante', 'é'), ('Importante', 'quantos'), ('Importante', 'passos'), ('Importante', 'agora'), ('Importante', 'você'), ('Importante', 'vai'), ('Importante', 'dar'), ('Importante', 'pra'), ('Importante', 'frente'), ('mesmo', 'é'), ('mesmo', 'quantos'), ('mesmo', 'passos'), ('mesmo', 'agora'), ('mesmo', 'você'), ('mesmo', 'vai'), ('mesmo', 'dar'), ('mesmo', 'pra'), ('mesmo', 'frente'), ('é', 'quantos'), ('é', 'passos'), ('é', 'agora'), ('é', 'você'), ('é', 'vai'), ('é', 'dar'), ('é', 'pra'), ('é', 'frente'), ('quantos', 'passos'), ('quantos', 'agora'), ('quantos', 'você'), ('quantos', 'vai'), ('quantos', 'dar'), ('quantos', 'pra'), ('quantos', 'frente'), ('passos', 'agora'), ('passos', 'você'), ('passos', 'vai'), ('passos', 'dar'), ('passos', 'pra'), ('passos', 'frente'), ('agora', 'você'), ('agora', 'vai'), ('agora', 'dar'), ('agora', 'pra'), ('agora', 'frente'), ('você', 'vai'), ('você', 'dar'), ('você', 'pra'), ('você', 'frente'), ('vai', 'dar'), ('vai', 'pra'), ('vai', 'frente'), ('dar', 'pra'), ('dar', 'frente'), ('pra', 'frente'), ('É', 'preciso'), ('É', 'que'), ('É', 'se'), ('É', 'mude'), ('É', 'o'), ('É', 'jeito'), ('É', 'de'), ('É', 'agirProcurando'), ('É', 'sempre'), ('É', 'dar'), ('É', 'passados'), ('É', 'para'), ('É', 'frente'), ('preciso', 'que'), ('preciso', 'se'), ('preciso', 'mude'), ('preciso', 'o'), ('preciso', 'jeito'), ('preciso', 'de'), ('preciso', 'agirProcurando'), ('preciso', 'sempre'), ('preciso', 'dar'), ('preciso', 'passados'), ('preciso', 'para'), ('preciso', 'frente'), ('que', 'se'), ('que', 'mude'), ('que', 'o'), ('que', 'jeito'), ('que', 'de'), ('que', 'agirProcurando'), ('q ...

# %%
G = nx.Graph(edgelist)
index = nx.betweenness_centrality(G)
sorted_index = sorted(index.items(), key=lambda x:x[1], reverse=True)
for word, centr in sorted_index[:10]:
  print(word, centr)
# Out:
# que 0.12399193548387095
# para 0.12399193548387095
# dar 0.08044354838709677
# frente 0.08044354838709677
# quantos 0.0532258064516129
# passos 0.0532258064516129
# você 0.0532258064516129
# Existe 0.0
# um 0.0
# provérbio 0.0

# %%
plt.rc('figure', figsize=(22, 7))
# G.remove_nodes_from([n for n in index if index[n] == .0])
node_size = [index[n]*10000 for n in G]

# %%
pos = nx.spring_layout(G)
nx.draw_networkx(G, pos, node_size=node_size, edge_color='b', alpha=.4, linewidths=1)
plt.show()
